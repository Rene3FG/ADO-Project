# %% [markdown]
# # Sistema de Control de Autobuses — ADO Oaxaca
# **Practicum I · Universidad Anáhuac Oaxaca, 2026**

# %%
import pandas as pd
from datetime import datetime

print('Entorno listo')

# %% [markdown]
# ## Datos de ejemplo

# %%
autobuses = pd.DataFrame({
    'numero_unidad': [101, 102, 103],
    'placa':         ['OAX-001', 'OAX-002', 'OAX-003'],
    'area_actual':   ['Recepción', 'Mecánica', 'Lavado'],
    'estado':        ['En proceso', 'En proceso', 'Disponible'],
    'ultima_actualizacion': [datetime.now()] * 3
})

autobuses
